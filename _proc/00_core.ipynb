# %% [raw]
# ---
# description: Read and query chronicle parquet files.
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## read_chronicle

# %%
#| echo: false
#| output: asis
show_doc(read_chronicle)
# Out:
# ---
#
# [source](https://github.com/andrie/py-chronicle/blob/main/py_chronicle/core.py#L16){target="_blank" style="float:right; font-size:smaller"}
#
# ### read_chronicle
#
# >      read_chronicle (dataset:str)
#
# Read a chronicle parquet file into a polars dataframe.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | dataset | str | Path to dataset |
# | **Returns** | **DataFrame** |  |

# %%
z = read_chronicle("./data/v1/metrics")
assert type(z) == pl.dataframe.frame.DataFrame

z = read_chronicle("./data/v1/logs")
assert type(z) == pl.dataframe.frame.DataFrame

# %% [markdown]
# ## describe_measures

# %%
#| echo: false
#| output: asis
show_doc(describe_measures)
# Out:
# ---
#
# [source](https://github.com/andrie/py-chronicle/blob/main/py_chronicle/core.py#L23){target="_blank" style="float:right; font-size:smaller"}
#
# ### describe_measures
#
# >      describe_measures (x:polars.dataframe.frame.DataFrame)
#
# Reads metrics dataframe and returns a pandas dataframe with summary of service, name and description of all metrics
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | x | DataFrame | metrics dataframe |
# | **Returns** | **DataFrame** |  |

# %%
m = read_chronicle("./data/v1/metrics/")
describe_measures(m)

# %% [markdown]
# ## get_metric_values

# %%
#| echo: false
#| output: asis
show_doc(get_metric_values)
# Out:
# ---
#
# [source](https://github.com/andrie/py-chronicle/blob/main/py_chronicle/core.py#L39){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_metric_values
#
# >      get_metric_values (x:polars.dataframe.frame.DataFrame, name:str,
# >                         alias:str)
#
# Extract a single metric from a metrics dataframe
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | x | DataFrame | metrics dataframe |
# | name | str | name of metric to extract |
# | alias | str | alias to use for new column |
# | **Returns** | **DataFrame** |  |

# %%
m = read_chronicle("./data/v1/metrics/")
get_metric_values(m, "cpu_percent", "cpu")

# %%
#| echo: false
#| output: asis
show_doc(plot_metric_values)
# Out:
# ---
#
# [source](https://github.com/andrie/py-chronicle/blob/main/py_chronicle/core.py#L60){target="_blank" style="float:right; font-size:smaller"}
#
# ### plot_metric_values
#
# >      plot_metric_values (x:polars.dataframe.frame.DataFrame, name:str,
# >                          alias:str)
#
# Plot a selected metric using a Plotly line plot
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | x | DataFrame | metrics dataframe |
# | name | str | name of metric to extract |
# | alias | str | alias to use for new column |
# | **Returns** | **line** |  |

# %%
m = read_chronicle("./data/v1/metrics/")
p = plot_metric_values(m, "cpu_percent", "cpu")
assert str(type(p)) == "<class 'plotly.graph_objs._figure.Figure'>"
# str(type(p))
